# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("SampleSuperstore_with_OrderDate.csv")

# %%
df.head()
# Out:
#   Order Date        Ship_mod    Segment        Country             City  \
# 0  5/11/2021    Second Class   Consumer  United States        Henderson
# 1   2/5/2024    Second Class   Consumer  United States        Henderson
# 2  8/15/2023    Second Class  Corporate  United States      Los Angeles
# 3  10/4/2022  Standard Class   Consumer  United States  Fort Lauderdale
# 4  9/25/2022  Standard Class   Consumer  United States  Fort Lauderdale
#
#         State  Postal Code Region         Category Sub-Category     Sales  \
# 0    Kentucky        42420  South        Furniture    Bookcases  261.9600
# 1    Kentucky        42420  South        Furniture       Chairs  731.9400
# 2  California        90036   West  Office Supplies       Labels   14.6200
# 3     Florida        33311  South        Furniture       Tables  957.5775
# 4     Florida        33311  South  Office Supplies      Storage   22.3680
#
#    Quantity  Discount    Profit
# 0         2      0.00   41.9136
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Order Date        Ship_mod    Segment        Country             City  \
# 0      5/11/2021    Second Class   Consumer  United States        Henderson
# 1       2/5/2024    Second Class   Consumer  United States        Henderson
# 2      8/15/2023    Second Class  Corporate  United States      Los Angeles
# 3      10/4/2022  Standard Class   Consumer  United States  Fort Lauderdale
# 4      9/25/2022  Standard Class   Consumer  United States  Fort Lauderdale
# ...          ...             ...        ...            ...              ...
# 9989   5/21/2023    Second Class   Consumer  United States            Miami
# 9990   4/10/2022  Standard Class   Consumer  United States       Costa Mesa
# 9991  11/23/2021  Standard Class   Consumer  United States       Costa Mesa
# 9992    9/1/2024  Standard Class   Consumer  United States       Costa Mesa
# 9993    9/4/2021    Second Class   Consumer  United States      Westminster
#
# ...

# %%
df.shape
# Out:
# (9994, 14)

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship_mod', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Category', 'Sub-Category', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Order Date      0
# Ship_mod        0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df['Sales'].sum()
# Out:
# np.float64(2297200.8603)

# %%
df['Profit'].sum()
# Out:
# np.float64(286397.0217)

# %%
df['Sales'].count()
# Out:
# np.int64(9994)

# %%
df.shape[0]
# Out:
# 9994

# %%
df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %%
df.groupby('Category')['Profit'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %%
df.groupby('Category')['Profit'].sum().sort_values()
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
# Out:
# Region
# West       725457.8245
# East       678781.2400
# Central    501239.8908
# South      391721.9050
# Name: Sales, dtype: float64

# %%
df.groupby('Region')['Profit'].sum().sort_values(ascending=False)
# Out:
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.groupby(df['Order Date'].dt.year).size()
# Out:
# Order Date
# 2021    2532
# 2022    2526
# 2023    2479
# 2024    2457
# dtype: int64

# %%
df.groupby(df['Order Date'].dt.year).size().sort_values(ascending=False).head(1)
# Out:
# Order Date
# 2021    2532
# dtype: int64

# %%
df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False).head(1)
# Out:
# Sub-Category
# Phones    330007.054
# Name: Sales, dtype: float64

# %%
print(df.columns.tolist())
# Out:
# ['Order Date', 'Ship_mod', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
df['Ship_mod'].value_counts().head(1)
# Out:
# Ship_mod
# Standard Class    5968
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Order Date      0
# Ship_mod        0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df['Discount'].mean()
# Out:
# np.float64(0.1562027216329798)

# %%
df['Profit'].mean()
# Out:
# np.float64(28.65689630778467)
